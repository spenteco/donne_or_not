# %%
import json

f = open('data/vectorized_lines.json', 'r', encoding='utf-8')
vectorized_lines = json.load(f)
f.close()

print(len(vectorized_lines))
print(vectorized_lines[0])
# Out:
# 58488
# {'line_text': ['WAS', 'CAR', 'then', 'Crashawe', ';', 'or', 'WAS', 'Crashawe', 'CAR', ','], 'line_pos': ['vvd', 'nn1', 'av', 'nn1', '', 'cc', 'vvd', 'nn1', 'nn1', ''], 'line_arpabet': ['w/aa/z', 'k/aa/r', 'dh/eh/n', 'k/r/ae/sh/ey', '', 'ao/r', 'w/aa/z', 'k/r/ae/sh/ey', 'k/aa/r', ''], 'line_ipa': ['w/ɑ/z', 'k/ɑ/ɹ', 'ð/ɛ/n', 'k/ɹ/æ/ʃ/eɪ', '', 'ɔ/ɹ', 'w/ɑ/z', 'k/ɹ/æ/ʃ/eɪ', 'k/ɑ/ɹ', ''], 'line_hayes_features': ['011011001000100000011000001010/010011001000000001001000100010/100100101100000000000001000010', '010000100000100000000000000000/010011001000000001001000100010/100010001010000000001000000010', '100100101110000000000000000010/010010001001000000001000100010/100100100000000000101000000010', '010000100000100000000000000000/100010001010000000001000000010/010010001001000001001000100010/100000101110000000000001000000/010010001001010000001000101010', '', '011011001000000000011000100010/100010001010000000001000000010', '011011001000100000011000001010/010011001000000001001000100010/100100101100000000000001000010', '010000100000100000000000000000/100010001010000000001000000010/010010001001000001001000100010/100000101110000000000001000000/010010001001010000001000101010', '010000100000100000000000000000/010011001000000001001000100010/100010001010000000001000000010', ''], 'line_v_c': ['C/V/C', 'C/V/C', 'C/V/C', 'C/C/V/C/V', '', 'V/C', 'C/V/C', 'C/C/V/C/V', 'C/V/C', ''], 'n_syllables': 10, 'rhyme_word': 'CAR', 'rhyme_arpabet': 'aa/r', 'rhyme_ipa': 'ɑ/ɹ', 'rhyme_hayes': '010011001000000001001000100010/100010001010000000001000000010', 'tcp_id': 'A80774', 'author': 'Crashaw', 'p_number': 0, 'l_number': 0}

# %%
lines_by_author = {}

for l in vectorized_lines:
    if l['author'] not in lines_by_author:
        lines_by_author[l['author']] = []
    lines_by_author[l['author']].append(l)
    
for author, lines in lines_by_author.items():
    print(author, len(lines))
    
author_names = sorted(list(lines_by_author.keys()))

print()
print(author_names)
# Out:
# Crashaw 8545
# Donne 13346
# Marvell 8418
# Vaughan 8893
# Rochester 3875
# Herbert 5420
# Herrick 9991
#
# ['Crashaw', 'Donne', 'Herbert', 'Herrick', 'Marvell', 'Rochester', 'Vaughan']

# %%
import numpy as np
import string
from nltk.corpus import stopwords

sw = set(stopwords.words('english'))

def lines_to_phoneme_features(lines, relative_frequency=False, consonants_only=False):
    
    all_lines_features = []
    
    for l in lines:
        
        l_features = [0 for a in range(0, 30)]
        n_features = 0
        
        hayes = '/'.join(l['line_hayes_features']).split('/')
        vc = '/'.join(l['line_v_c']).split('/')
        
        if len(hayes) == len(vc):
        
            for ha, h in enumerate(hayes):

                i_features = [int(c) for c in h]

                for a, i in enumerate(i_features):

                    if consonants_only == False or vc[ha] == 'C':

                        l_features[a] += i
                        n_features += i

            if relative_frequency == True:
                for a in range(0, len(l_features)):
                    l_features[a] = float(l_features[a]) / float(n_features)

            all_lines_features.append(l_features)

    return all_lines_features

# -----------------------------------------------------------------------------------

features_by_author = {}

for author, lines in lines_by_author.items():
    
    phoneme_features_by_author[author] = []
    
    for line in lines:
        
        try:
            features = []

            phonetic_data = lines_to_phoneme_features([line], 
                                                       relative_frequency=False,
                                                       consonants_only=False)
            features.append(phonetic_data[0])
                        
            features.append([w.strip().lower() for w in line['line_text'] 
                              if w.strip() > '' and w.strip().lower() not in string.punctuation and 
                                 w.strip().lower() not in sw])

            phoneme_features_by_author[author].append(features)
            
        except IndexError:
            pass
                        
print(len(phoneme_features_by_author))
print()
print(phoneme_features_by_author['Donne'][0])
# Out:
# 7
#
# [[17, 14, 7, 14, 15, 5, 19, 0, 24, 9, 8, 6, 8, 1, 1, 0, 0, 4, 4, 4, 19, 0, 0, 3, 10, 0, 4, 0, 23, 0], ['youth', 'strength', 'mirth', 'wit', 'time']]

# %%
import random
import numpy as np

from sklearn.naive_bayes import *
from sklearn import tree, svm
from sklearn.linear_model import *
from sklearn.ensemble import *
from sklearn.preprocessing import *
    
    
from gensim import corpora
from gensim.matutils import *

# -----------------------------------------------------------------------------------
        
for a in range(0, len(author_names)):
    
    for b in range(0, len(author_names)):
        
        if a == b:
            continue
            
        #if b != 0:
        #    continue
    
        print()
        print('----------------------------------------------')
        print()
        print(author_names[a], 'vs.', author_names[b])
        print()
        
        a_lines = phoneme_features_by_author[author_names[a]]
        b_lines = phoneme_features_by_author[author_names[b]]
        
        random.shuffle(a_lines)
        random.shuffle(b_lines)
        
        min_lines = len(a_lines)
        if len(b_lines) < min_lines:
            min_lines = len(b_lines)
        
        all_training_data = a_lines[:3000] + b_lines[:3000]
        all_testing_data = a_lines[3000:min_lines] + b_lines[3000: min_lines]
        
        training_labels = [author_names[a] for l in a_lines[:3000]] + \
                            [author_names[b] for l in b_lines[:3000]]
        testing_labels = [author_names[a] for l in a_lines[3000:min_lines]] + \
                            [author_names[b] for l in b_lines[3000:min_lines]]
            
        training_phone_data = [l[0] for l in all_training_data]
        testing_phone_data = [l[0] for l in all_testing_data]
        
        # ----------------------------------------------------------------------------

        clf = RandomForestClassifier().fit(training_phone_data, training_labels)
        
        score = clf.score(testing_phone_data, testing_labels)
        
        print('\t', 'phonemes RandomForestClassifier', score)
        
        # ----------------------------------------------------------------------------
        
        training_text_data = [l[1] for l in all_training_data]
        testing_text_data = [l[1] for l in all_testing_data]
        
        dictionary = corpora.Dictionary(training_text_data + testing_text_data)
        
        training_corpus = [dictionary.doc2bow(text) for text in training_text_data]
        testing_corpus = [dictionary.doc2bow(text) for text in testing_text_data]
        
        training_matrix = corpus2dense(training_corpus, len(dictionary))
        training_matrix = training_matrix.T
        
        testing_matrix = corpus2dense(testing_corpus, len(dictionary))
        testing_matrix = testing_matrix.T
        
        # ----------------------------------------------------------------------------

        clf = RandomForestClassifier().fit(training_matrix, training_labels)
        
        score = clf.score(testing_matrix, testing_labels)
        
        print('\t', 'text RandomForestClassifier', score)
        
        # ----------------------------------------------------------------------------
        
        
print()
print('ok!')
# Out:
# ----------------------------------------------
#
# Crashaw vs. Donne
#
# 	 phonemes RandomForestClassifier 0.7658250676284941
# 	 text RandomForestClassifier 0.7185752930568079
#
# ----------------------------------------------
#
# Crashaw vs. Herbert
#
# 	 phonemes RandomForestClassifier 0.6495867768595042
# 	 text RandomForestClassifier 0.7256198347107438
#
# ----------------------------------------------
#
# Crashaw vs. Herrick
#
# 	 phonemes RandomForestClassifier 0.630297565374211
# 	 text RandomForestClassifier 0.7192966636609558
#
# ----------------------------------------------
#
# Crashaw vs. Marvell
#
# 	 phonemes RandomForestClassifier 0.6665741768405475
# 	 text RandomForestClassifier 0.6778579356270811
#
# ----------------------------------------------
#
# Crashaw vs. Rochester
#
# 	 phonemes RandomForestClassifier 0.681350114416476
# 	 text RandomForestClassifier 0.717391304347826
#
# ----------------------------------------------
#
# Crashaw vs. Vaughan
#
# 	 phonemes RandomForestClassifier 0.6412984670874662
# 	 text RandomForestClassifier 0.6515779981965735
#
# ----------------------------------------------
#
# Donne vs. Crashaw
#
# 	 phonemes RandomForestClassifier 0.7715058611361587
# 	 text RandomForestClassifier 0.724346257889991
#
# ----------------------------------------------
#
# Donne vs. Herbert
#
# 	 phonemes RandomForestClassifier 0.6869834710743802
# 	 text RandomForestClassifier 0.6642561983471075
#
# ----------------------------------------------
#
# Donne vs. Herrick
#
# 	 phonemes RandomForestClassifier 0.7616936060649406
# 	 text RandomForestClassifier 0.6663567443856386
#
# ----------------------------------------------
#
# Donne vs. Marvell
#
# 	 phonemes RandomForestClassifier 0.6551979282278949
# 	 text RandomForestClassifier 0.6267110617832038
#
# ----------------------------------------------
#
# Donne vs. Rochester
#
# 	 phonemes RandomForestClassifier 0.683066361556064
# 	 text RandomForestClassifier 0.6853546910755148
#
# ----------------------------------------------
#
# Donne vs. Vaughan
#
# 	 phonemes RandomForestClassifier 0.6989986422267481
# 	 text RandomForestClassifier 0.6393414799728445
#
# ----------------------------------------------
#
# Herbert vs. Crashaw
#
# 	 phonemes RandomForestClassifier 0.6632231404958677
# 	 text RandomForestClassifier 0.7235537190082645
#
# ----------------------------------------------
#
# Herbert vs. Donne
#
# 	 phonemes RandomForestClassifier 0.6940082644628099
# 	 text RandomForestClassifier 0.6483471074380165
#
# ----------------------------------------------
#
# Herbert vs. Herrick
#
# 	 phonemes RandomForestClassifier 0.6002066115702479
# 	 text RandomForestClassifier 0.6568181818181819
#
# ----------------------------------------------
#
# Herbert vs. Marvell
#
# 	 phonemes RandomForestClassifier 0.6295454545454545
# 	 text RandomForestClassifier 0.6506198347107438
#
# ----------------------------------------------
#
# Herbert vs. Rochester
#
# 	 phonemes RandomForestClassifier 0.6310068649885584
# 	 text RandomForestClassifier 0.6836384439359268
#
# ----------------------------------------------
#
# Herbert vs. Vaughan
#
# 	 phonemes RandomForestClassifier 0.5679752066115702
# 	 text RandomForestClassifier 0.609297520661157
#
# ----------------------------------------------
#
# Herrick vs. Crashaw
#
# 	 phonemes RandomForestClassifier 0.642200180342651
# 	 text RandomForestClassifier 0.7267808836789901
#
# ----------------------------------------------
#
# Herrick vs. Donne
#
# 	 phonemes RandomForestClassifier 0.7586182234301244
# 	 text RandomForestClassifier 0.6645687312258618
#
# ----------------------------------------------
#
# Herrick vs. Herbert
#
# 	 phonemes RandomForestClassifier 0.5960743801652892
# 	 text RandomForestClassifier 0.6830578512396694
#
# ----------------------------------------------
#
# Herrick vs. Marvell
#
# 	 phonemes RandomForestClassifier 0.6453940066592675
# 	 text RandomForestClassifier 0.6431742508324084
#
# ----------------------------------------------
#
# Herrick vs. Rochester
#
# 	 phonemes RandomForestClassifier 0.6590389016018307
# 	 text RandomForestClassifier 0.6739130434782609
#
# ----------------------------------------------
#
# Herrick vs. Vaughan
#
# 	 phonemes RandomForestClassifier 0.6121011541072641
# 	 text RandomForestClassifier 0.643754243041412
#
# ----------------------------------------------
#
# Marvell vs. Crashaw
#
# 	 phonemes RandomForestClassifier 0.6743433222345542
# 	 text RandomForestClassifier 0.6859970403255642
#
# ----------------------------------------------
#
# Marvell vs. Donne
#
# 	 phonemes RandomForestClassifier 0.6610247872734
# 	 text RandomForestClassifier 0.6718460969293377
#
# ----------------------------------------------
#
# Marvell vs. Herbert
#
# 	 phonemes RandomForestClassifier 0.6305785123966943
# 	 text RandomForestClassifier 0.6555785123966942
#
# ----------------------------------------------
#
# Marvell vs. Herrick
#
# 	 phonemes RandomForestClassifier 0.6502034776174621
# 	 text RandomForestClassifier 0.6486311505734369
#
# ----------------------------------------------
#
# Marvell vs. Rochester
#
# 	 phonemes RandomForestClassifier 0.5715102974828375
# 	 text RandomForestClassifier 0.6521739130434783
#
# ----------------------------------------------
#
# Marvell vs. Vaughan
#
# 	 phonemes RandomForestClassifier 0.5841657417684055
# 	 text RandomForestClassifier 0.6154273029966704
#
# ----------------------------------------------
#
# Rochester vs. Crashaw
#
# 	 phonemes RandomForestClassifier 0.6636155606407322
# 	 text RandomForestClassifier 0.6950800915331807
#
# ----------------------------------------------
#
# Rochester vs. Donne
#
# 	 phonemes RandomForestClassifier 0.6544622425629291
# 	 text RandomForestClassifier 0.6802059496567505
#
# ----------------------------------------------
#
# Rochester vs. Herbert
#
# 	 phonemes RandomForestClassifier 0.6104118993135011
# 	 text RandomForestClassifier 0.6876430205949656
#
# ----------------------------------------------
#
# Rochester vs. Herrick
#
# 	 phonemes RandomForestClassifier 0.6584668192219679
# 	 text RandomForestClassifier 0.6756292906178489
#
# ----------------------------------------------
#
# Rochester vs. Marvell
#
# 	 phonemes RandomForestClassifier 0.5554919908466819
# 	 text RandomForestClassifier 0.6624713958810069
#
# ----------------------------------------------
#
# Rochester vs. Vaughan
#
# 	 phonemes RandomForestClassifier 0.5966819221967964
# 	 text RandomForestClassifier 0.6887871853546911
#
# ----------------------------------------------
#
# Vaughan vs. Crashaw
#
# 	 phonemes RandomForestClassifier 0.6403065825067629
# 	 text RandomForestClassifier 0.6642019837691614
#
# ----------------------------------------------
#
# Vaughan vs. Donne
#
# 	 phonemes RandomForestClassifier 0.6882213170400543
# 	 text RandomForestClassifier 0.6398506449422946
#
# ----------------------------------------------
#
# Vaughan vs. Herbert
#
# 	 phonemes RandomForestClassifier 0.5791322314049587
# 	 text RandomForestClassifier 0.6111570247933884
#
# ----------------------------------------------
#
# Vaughan vs. Herrick
#
# 	 phonemes RandomForestClassifier 0.6100644942294636
# 	 text RandomForestClassifier 0.6591989137813985
#
# ----------------------------------------------
#
# Vaughan vs. Marvell
#
# 	 phonemes RandomForestClassifier 0.5924898261191269
# 	 text RandomForestClassifier 0.6277284498705142
#
# ----------------------------------------------
#
# Vaughan vs. Rochester
#
# 	 phonemes RandomForestClassifier 0.6275743707093822
# 	 text RandomForestClassifier 0.6670480549199085
#
# ok!
